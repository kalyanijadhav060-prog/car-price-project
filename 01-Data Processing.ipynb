# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings		
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('car-pred.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    str
#  1   company     892 non-null    str
#  2   year        892 non-null    str
#  3   Price       892 non-null    str
#  4   kms_driven  840 non-null    str
#  5   fuel_type   837 non-null    str
# dtypes: str(6)
# memory usage: 41.9 KB

# %%
#yaer column cleaning
df['year'].unique()
df['year'] = pd.to_numeric(df['year'],errors='coerce')

# %%
df['year'].unique()
# Out:
# array([2007., 2006., 2018., 2014., 2015., 2012., 2013., 2016., 2010.,
#        2017., 2008., 2011., 2019., 2009., 2005., 2000.,   nan, 2003.,
#        2004., 1995., 2002., 2001.])

# %%
df.dropna(subset=['year'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    str
#  1   company     842 non-null    str
#  2   year        842 non-null    float64
#  3   Price       842 non-null    str
#  4   kms_driven  840 non-null    str
#  5   fuel_type   837 non-null    str
# dtypes: float64(1), str(5)
# memory usage: 46.0 KB

# %%
df['fuel_type'].unique()
# Out:
# <StringArray>
# ['Petrol', 'Diesel', nan, 'LPG']
# Length: 4, dtype: str

# %%
df.duplicated().value_counts()
# Out:
# False    749
# True      93
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.duplicated().value_counts()
# Out:
# False    749
# Name: count, dtype: int64

# %%
df['year'].unique()
# Out:
# array([2007., 2006., 2018., 2014., 2015., 2012., 2013., 2016., 2010.,
#        2017., 2008., 2011., 2019., 2009., 2005., 2000., 2003., 2004.,
#        1995., 2002., 2001.])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 749 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        749 non-null    str
#  1   company     749 non-null    str
#  2   year        749 non-null    float64
#  3   Price       749 non-null    str
#  4   kms_driven  748 non-null    str
#  5   fuel_type   745 non-null    str
# dtypes: float64(1), str(5)
# memory usage: 41.0 KB

# %%
df['Price'] = df['Price'].str.replace(",","")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 749 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        749 non-null    str
#  1   company     749 non-null    str
#  2   year        749 non-null    float64
#  3   Price       749 non-null    str
#  4   kms_driven  748 non-null    str
#  5   fuel_type   745 non-null    str
# dtypes: float64(1), str(5)
# memory usage: 41.0 KB

# %%
df['Price'] = pd.to_numeric(df['Price'],errors='coerce')
df.dropna(subset=['Price'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 727 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        727 non-null    str
#  1   company     727 non-null    str
#  2   year        727 non-null    float64
#  3   Price       727 non-null    float64
#  4   kms_driven  727 non-null    str
#  5   fuel_type   724 non-null    str
# dtypes: float64(2), str(4)
# memory usage: 39.8 KB

# %%
df['year'] =df['year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 727 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        727 non-null    str
#  1   company     727 non-null    str
#  2   year        727 non-null    int64
#  3   Price       727 non-null    float64
#  4   kms_driven  727 non-null    str
#  5   fuel_type   724 non-null    str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 39.8 KB

# %%
df["kms_driven"] = df["kms_driven"].str.replace(",", "")

# %%
df["kms_driven"] = df["kms_driven"].str.replace(" kms", "")

# %%
df["kms_driven"] = pd.to_numeric(df["kms_driven"], errors = 'coerce')
df.dropna(subset = ['kms_driven'], inplace = True)
df['kms_driven']= df['kms_driven'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 725 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        725 non-null    str
#  1   company     725 non-null    str
#  2   year        725 non-null    int64
#  3   Price       725 non-null    float64
#  4   kms_driven  725 non-null    int64
#  5   fuel_type   724 non-null    str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 39.6 KB

# %%
#fuel type cleaning
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 725 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        725 non-null    str
#  1   company     725 non-null    str
#  2   year        725 non-null    int64
#  3   Price       725 non-null    float64
#  4   kms_driven  725 non-null    int64
#  5   fuel_type   724 non-null    str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 39.6 KB

# %%
df.dropna(inplace=True)
#filtering only petrol and diseal records
df=df[df["fuel_type"]!="LPG"]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 722 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        722 non-null    str
#  1   company     722 non-null    str
#  2   year        722 non-null    int64
#  3   Price       722 non-null    float64
#  4   kms_driven  722 non-null    int64
#  5   fuel_type   722 non-null    str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 39.5 KB

# %%
#clean company column
df["company"].unique()
# Out:
# <StringArray>
# [   'Hyundai',   'Mahindra',       'Ford',     'Maruti',      'Skoda',
#        'Audi',     'Toyota',    'Renault',      'Honda',     'Datsun',
#  'Mitsubishi',       'Tata', 'Volkswagen',  'Chevrolet',       'Mini',
#         'BMW',     'Nissan',  'Hindustan',       'Fiat',      'Force',
#    'Mercedes',       'Land',     'Jaguar',       'Jeep',      'Volvo']
# Length: 25, dtype: str

# %%
#clean name column
#replace company name take only 2 words
for i in df.index:
    name=df.loc[i,"name"]
    names=name.split()
    df.loc[i,"name"]=" ".join(names[1:3])

# %%
df["company"]
# Out:
# 0       Hyundai
# 1      Mahindra
# 3       Hyundai
# 4          Ford
# 6          Ford
#          ...
# 883      Maruti
# 885        Tata
# 886      Toyota
# 888        Tata
# 889    Mahindra
# Name: company, Length: 722, dtype: str

# %%
#check if duplicates records
df.drop_duplicates(inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    718
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 718 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        718 non-null    str
#  1   company     718 non-null    str
#  2   year        718 non-null    int64
#  3   Price       718 non-null    float64
#  4   kms_driven  718 non-null    int64
#  5   fuel_type   718 non-null    str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 39.3 KB

# %%
df.to_csv("cleaned_data.csv",index=False)
